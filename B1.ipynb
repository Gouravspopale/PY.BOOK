# %% [markdown]
# BUSINESS STATISTICS

# %%
import statistics as st 

x=[1,2,3,4,5,6,7,8,9]
#  it is the sum of observation divided by the total number of observation
print(st.mean(x))
# Out:
# 5

# %%
import statistics as st 

x=[1,2,3,4,5,6,7,8,9]
#  it is value most frequently arrived in sample set
print(st.mode(x))
# Out:
# 2

# %%
import statistics as st 

x=[1,2,3,4,5,6,7,8,9]
#  it is the measure of central value of sample set
print(st.median(x))
# Out:
# 5

# %%
import statistics as st 
#  to print standereddevation
x=[1,2,3,4,5,6,7,8,9]
print(st.stdev(x))
# Out:
# 2.7386127875258306

# %% [markdown]
# HISTOGRAM GRAPH

# %%
import pandas as pd
import matplotlib.pyplot as plt
  
# create 2D array of table given above
data = [['GOURAV',   10, 24,1000],
        ['DARSHAN',  15, 40,2000],
        ['SAMARTH',  20, 27,3000],
        ['SHANKAR',  25, 30,7000],
        ['JOEL',     30, 15,9000],
        ['VINAYAK',  35, 36,5000],
        ['ROHAN',    40, 22,10000]]
        
# dataframe created with
# the above data array
df = pd.DataFrame(data, columns = ['NAME', 'ROLL NUBER', 'AGE',"SALARY"] )
  
# create histogram for numeric data
df.hist()
  
# show plot to print graph
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
  
# create 2D array of table given above
data = [['GOURAV',   1, 55,1000],
        ['DARSHAN',  9, 45,2000],
        ['SAMARTH',  2, 45,3000],
        ['SHANKAR',  5, 40,7000],
        ['JOEL',     3, 57,9000],
        ['VINAYAK',  6, 36,5000],
        ['ROHAN',    2, 42,10000]]
df=pd.DataFrame(data,columns=["NAME","ROLL NUMBER","AGE","SALARY"])       
df.plot.bar()
plt.bar(df["ROLL NUMBER"],df["AGE"],df["SALARY"])
# plt.xlabel("NAME")
plt.xlabel("ROLL NUMBER")
plt.xlabel("AGE")
plt.xlabel("SALARY")
plt.show()

# %%
import pandas
import matplotlib.pyplot as plt

data=[50,26,48,79,89,99]
plt.pie(data,labels={"sb1","sb2","sb3","sb4","sb5","sb6"},autopct='% 1.2f%%',shadow=True)
plt.show()

# %%
import pandas
import matplotlib.pyplot as plt

# linewidths- width of marker border
# edgecolor- marker border color

age=[23,32,45,52,66,75]
income=[2000,3000,4000,5000,6000,7000]

# x_axis_data- An array containing x-axis data
# y_axis_data- An array containing y-axis data
# s- marker size (can be scalar or array of size equal to size of x or y)

plt.scatter(income,age,c ="black",linewidths=2,marker="s",edgecolor="red",s=50)
plt.xlabel("income")
plt.ylabel("age")
plt.show()

# %%
# 
import pandas
import matplotlib.pyplot as plt
x1 = [5,10,15,20,25,30,35,40,45,50]
 
y1 = [50,45,40,35,30,25,20,15,10,5]
plt.scatter(x1, y1, c ="black",
            linewidths = 2,
            marker ="s",
            edgecolor ="purple",
            s = 50)

y2 = [50,45,40,35,30,25,20,15,10,5]
 
x2 = [50,45,40,35,30,25,20,15,10,5]
plt.scatter(x2, y2, c ="orange",
            linewidths = 2,
            marker ="^",
            edgecolor ="black",
            s = 50)
plt.xlabel("X-axis")
plt.ylabel("Y-axis")


plt.show()
