# %% [markdown]
# BUSINESS STATISTICS

# %% [markdown]
# Calculating MEAN( )

# %%
import statistics as st 

x=[1, 2, 3, 3, 2, 2, 2, 1]
#  it is the sum of observation divided by the total number of observation
print(st.mean(x))
# Out:
# 2

# %% [markdown]
# Calculating MODE( )

# %%
import statistics as st 

x=[1,2,3,4,5,6,7,8,9]
#  it is value most frequently arrived in sample set
print(st.mode(x))
# Out:
# 1

# %% [markdown]
# Calculating MEDIAN( ) with high median( ) and low median( )

# %%
import statistics as st 

x=[1, 3, 3, 4, 5, 7]
#  it is the measure of central value of sample set
print(st.median(x))
print(st.median_high(x))
print(st.median_low(x))
# Out:
# 3.5
# 4
# 3

# %% [markdown]
# Finding maximum and minimum from hole list

# %%
# Sample Data
arr = [1, 2, 3, 4, 5]

#Finding Max
Maximum = max(arr)
# Finding Min
Minimum = min(arr)

# Difference Of Max and Min
Range = Maximum-Minimum	
print("Maximum = {}, Minimum = {} and Range = {}".format(
	Maximum, Minimum, Range))
# Out:
# Maximum = 5, Minimum = 1 and Range = 4

# %% [markdown]
# Calculating Standard Deviation( )

# %%
import statistics as st 
#  to print standereddevation
x=[1,2,3,4,5,6,7,8,9]
print(st.stdev(x))
# Out:
# 2.7386127875258306

# %% [markdown]
#  PYTHON PROGRAM TO RE PRESENT HISTOGRAM GRAPH

# %%
# python program to print given data into a histogram graph 

import pandas as pd
import matplotlib.pyplot as plt
  
# create 2D array of table given above
data = [['GOURAV',   1, 14,100],
        ['DARSHAN',  2, 20,700],
        ['SAMARTH',  3, 22,800],
        ['SHANKAR',  4, 27,900],
        ['JOEL',     5, 30,200],
        ['VINAYAK',  6, 33,500],
        ['ROHAN',    7, 35,400]]
        
# dataframe created 
# DataFrame is a 2-dimensional labeled data structure with columns of potentially different types
df = pd.DataFrame(data, columns = [ 'name','ROLL NUBER', 'AGE',"SALARY"] )
  
# create histogram for numeric data
df.hist()
  
# show plot to print graph
plt.show()

# %% [markdown]
# PYTHON PROGRAM TO REPRESENT BAR GRAPH DIAGRAM

# %%
#  python program to print given data into Bar graph
#  program to print Total marks Obtained by a student for 100 (marks)

import pandas as pd
import matplotlib.pyplot as plt
  # create 2D array of table given above

data = {    111:85,
            112:89,
            113:72,
            114:58,
            115:90,
            116:50,
            117:97}

# Note:converting the data {Dictionary:To list Format}
Roll_no=list(data.keys())
Total_Marks=list(data.values())

# figsize() takes two parameters- width and height (in inches).to plot the Graph
fig = plt.figure(figsize = (4, 2))

# creating the bar plot
plt.bar(Roll_no,
        Total_Marks,
        color ='magenta',
        width = 0.5)

plt.xlabel("Roll Number")                      # X-axis
plt.ylabel("Mark's")                           # Y-axis
plt.title("Total Marks Obtained By Student ")

# to present the graph
plt.show()

# %%
#  python program to print given data into Bar graph
#  program to print employee salary With there Rspective (Age) with Bar Graph

import pandas as pd
import matplotlib.pyplot as plt
  
# create 2D array of table given above
data = {   "15" : 13000,
           "17" : 14000,
           "20" : 18000,
           "22" : 19000,
           "25" : 20000,
           "30" : 25000,
           "32" : 30000}

AGE=list(data.keys())       # picking only the keys
SALARY=list(data.values())  # picking only the values

fig = plt.figure(figsize =(4, 3))

# creating the bar plot
plt.bar(AGE,SALARY, 
        color ='cyan',
        width = 0.5)

plt.xlabel("Age of Employee")
plt.ylabel("Total Salary employee's")
plt.title("Salary of Employee's")

plt.show()

# %% [markdown]
#  PYTHON PROGRAM TO REPRESENT PIE CHART DIAGRAM

# %%
#  simple program to print pie chart
#  program to print student marks obtained by in each subject

import pandas
import matplotlib.pyplot as plt


# TOTAL MARKS OBTAINED IN PATICULAR SUBJECT
data=[50,26,48,79,89,99]

# PLOTING IT IN (PIE) with data and labels
plt.pie(data,labels={"sb1","sb2","sb3","sb4","sb5","sb6"},
        
        startangle=90,
        
        # allows us to display the percent value using string formatting.
        autopct='% 1.2f%%',
         # shadow of piechar
        shadow=True) 

plt.show()

# %%
# piechart to check to linewidth,edgecolor,

import pandas
import matplotlib.pyplot as plt


# TOTAL MARKS OBTAINED IN PATICULAR SUBJECT
data=["sb1","sb2","sb3","sb4","sb5","sb6","sb7"]


area = [25, 20, 15, 10,15,10,5]
explode = (0.1, 0, 0.1, 0,0.1,0.1,0.1) 


# PLOTING IT IN (PIE) with data and labels
plt.pie(area, 
        explode = explode, 
        labels = data,
        autopct='% 1.2f%%',
        startangle=180,
        # a string or function used to label the wedges with their numeric value,
        
        wedgeprops ={"edgecolor" : "black",
                    'linewidth' : 1,
                    'antialiased': True,
                     },shadow=True)
  
        
plt.axis('equal') 
plt.show()

# %% [markdown]
# Slices of pie chart

# %%
#  program to slice the piechart by using Area, explode
import matplotlib.pyplot as plt
  
# the slices are ordered and 
# plotted counter-clockwise:
continents = ['Asia', 'Europe', 
              'North America','South America',
              'Australia','Africa','Antarctica']
  
area = [25, 20, 15, 10,15,10,5]
explode = (0.1, 0, 0.1, 0,0.1,0.1,0.1)

  
plt.pie(area, 
        explode = explode, labels = continents,
        autopct = '%1.1f%%',
        startangle =160,
        wedgeprops = {"edgecolor" : "black", # Each wedge represents a proportionate part of the whole
                      'linewidth' : 2,
                      'antialiased': True})
  
# Equal aspect ratio ensures that pie is drawn as a circle.
plt.axis('equal') 
  
plt.show()

# %% [markdown]
#  PYTHON PROGRAM TO REPRESENT SCATTER DIAGRAM

# %%
# program to print employee salary With there Rspective (Age) with scatter Graph 

import pandas
import matplotlib.pyplot as plt

age=[23,32,45,52,66,75]
income=[2000,3000,4000,5000,6000,7000]


plt.scatter(income,age,c ="cyan",
            linewidths=2,           # linewidths- width of marker border
            marker="s",             # s- marker size (can be scalar or array of size equal to size of x or y)
            edgecolor="black",        # edgecolor- marker border color
            s=50)

plt.xlabel("income")        # x_axis_data- An array containing x-axis data
plt.ylabel("age")           # y_axis_data- An array containing y-axis data
plt.show()

# %%
# program to print two graph by using x=axis,y-axis and adding diffrent colours 

import pandas
import matplotlib.pyplot as plt

x1 = [5,10,15,20,25,30,35,40,45,50]
y1 = [50,45,40,35,30,25,20,15,10,5]

plt.scatter(x1, y1, c ="black",
            linewidths = 2,
            marker ="s",
            edgecolor ="cyan",
            s = 50)

y2 = [50,45,40,35,30,25,20,15,10,5]
x2 = [50,45,40,35,30,25,20,15,10,5]

plt.scatter(x2, y2, c ="magenta",
            linewidths = 2,
            marker ="^",
            edgecolor ="black",
            s = 50)

plt.xlabel("X-axis")
plt.ylabel("Y-axis")

plt.show()

# %%
import numpy as np
# import scipy as sp
import matplotlib.pyplot as plt

# %matplotlib inline
k = np.arange(0,20)
x = np.cos(2*k*np.pi/4) 


plt.stem(k, x, use_line_collection=True)
# Out:
# C:\Users\User7\AppData\Local\Temp\ipykernel_9868\1417209040.py:10: MatplotlibDeprecationWarning: The 'use_line_collection' parameter of stem() was deprecated in Matplotlib 3.6 and will be removed two minor releases later. If any parameter follows 'use_line_collection', they should be passed as keyword, not positionally.
#   plt.stem(k, x, use_line_collection=True)
# <StemContainer object of 3 artists>

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.arange(0,10*np.pi,0.1)
y = np.sin(x)

plt.plot(x,y,color='red')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

vec = np.array([[-3],[2]])
origin = np.zeros(vec.shape) # origin point

plt.figure(figsize=(6,6))
plt.quiver(*origin, *vec, color=['b'], scale=1, units='xy')

plt.grid()
plt.xlim(-5,5)
plt.ylim(-5,5)
plt.gca().set_aspect('equal')
plt.show()
